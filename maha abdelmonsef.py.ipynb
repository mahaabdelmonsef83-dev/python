# %%
name = input("enter your name")
age = int(input("enter your age"))
print("hello" , name)
print("you are" , age , "years old")
# Out:
# enter your name maha
# enter your age 25
# hello maha
# you are 25 years old

# %%
length =float(input("enter length"))
width = float(input("enter width"))
area = length * width
print("the area =" ,  area)
# Out:
# enter length 20
# enter width 30
# the area = 600.0

# %%
import math

# %%
print("square root of the age" , math.sqrt(age))
# Out:
# square root of the age 5.0

# %%
print("age squared =" , math.pow(age,2))
# Out:
# age squared = 625.0

# %%
print("absolute difference =" , math.fabs(age - 50))
# Out:
# absolute difference = 25.0

# %%
print("ceiling of half the age" , math.ceil(0.5 * age))
# Out:
# ceiling of half the age 13

# %%
print("floor of half the age" , math.floor(0.5 * age))
# Out:
# floor of half the age 12
