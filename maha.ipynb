# %%
print("hello")
# Out:
# hello

# %%
print("hello world")
# Out:
# hello world

# %%
print("welcome to python") ; print("python is open source")
# Out:
# welcome to python
# python is open source

# %%
print("""welcom to python
welcome to dpi
welcom to data""")
# Out:
# welcom to python
# welcome to dpi
# welcom to data

# %%
print("Maha" , end = "-------------- ")
print("Abdelmonsef")
# Out:
# Maha-------------- Abdelmonsef

# %%
print("welcom" , "to" , "python", end = ".")
print("what is python" , end= ":")
print("python is open source")
# Out:
# welcom to python.what is python:python is open source

# %%
# comment -> Note
#this is my first program
print("hello world")
# Out:
# hello world

# %%
age = 40
print(age)
# Out:
# 40

# %%
name ="yamen bassam"
age = 5
print(name)
print(age)
# Out:
# yamen bassam
# 5

# %%
sales = 15000.155
print(sales)
# Out:
# 15000.155

# %%
is_student = True

print(is_student)
# Out:
# True

# %%
is_student = "true"  
print(is_student)
# Out:
# true

# %%
gender = "female"
print(gender)
# Out:
# female

# %%
name = "Maha aBDELMONSEF"
address = "ALEX"
age = 30
age = str(age)
print(type(age))
gender = "female"
print("full_name is:" , name)
print("address:" , address)
print("age:" , age )
print("gender:" , gender)
# Out:
# <class 'str'>
# full_name is: Maha aBDELMONSEF
# address: ALEX
# age: 30
# gender: female

# %%
sales = 30.45
print(sales)
print(type(sales))
# Out:
# 30.45
# <class 'float'>

# %%
num1 = 20
num2 = 2
num3 = num1 - num2
print(num3)
# Out:
# 48

# %%
sales= 25.8
print(int(sales))
print(str(sales))
# Out:
# 25
# 25.8

# %%
num1 = 9
num2 = 3
num3 = num1 * num2
num4 = num1 / num3
num5 = num1 // num2
num6 = num1 % num2
print(num3)
print(num4)
print (num5)
print(num6)
# Out:
# 27
# 0.3333333333333333
# 3
# 0

# %%
num1**2
# Out:
# 81

# %%
num2**2
# Out:
# 9

# %%
num5**2
# Out:
# 9

# %%
full_name = input("enter your name")
adress = input("enter your address")
age = input("enter your age")
gender = input("enter your gender")
# Out:
# enter your name maha
# enter your address alex
# enter your age 38
# enter your gender female

# %%
full_name = input("enter your name")
adress = input("enter your address")
age = input("enter your age")
gender = input("enter your gender")
print("full_name:" , full_name)
print("adress:" , adress)
print("age:" , age)
print("gender:" , gender)
# Out:
# enter your name yamen
# enter your address alex
# enter your age 5
# enter your gender male
# full_name: yamen
# adress: alex
# age: 5
# gender: male

# %%
quantity = int(input("enter quantity"))
price = int(input("enter price"))

total_amount = quantity * price  
print(total_amount)
# Out:
# enter quantity 20
# enter price 30
# 600

# %%
num1 = 25.7
print(round(num1))
# Out:
# 26

# %%
print(pow(2,4))
# Out:
# 16

# %%
import math

# %%
print(math.ceil(2.9))
print(math.ceil(2.7))
print(math.ceil(2.5))
print(math.ceil(2.1))
# Out:
# 3
# 3
# 3
# 3

# %%
print(math.floor(2.9))
print(math.floor(2.7))
print(math.floor(2.5))
print(math.floor(2.1))
# Out:
# 2
# 2
# 2
# 2

# %%
print(math.sqrt(81))
# Out:
# 9.0

# %%
print(math.fabs(-36))
# Out:
# 36.0

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
length = int(input("enter length"))
width = int(input("enter width"))
area = length * width
print("the area is:" , area)
# Out:
# enter length 20
# enter width 10
# the area is: 200

# %%
length = math.fabs(int(input("enter length")))
width = math.fabs(int(input("enter width")))
area = length * width
print("the area is:" , area)
# Out:
# enter length -10
# enter width 20
# the area is: 200.0

# %%
radius = int(input("enter radius"))
area = math.pi * math.pow(radius,2)
print("the area is:" ,  area)
# Out:
# enter radius 20
# the area is: 1256.6370614359173

# %%
aradius=int(input("enter the radius"))
area = 3.14 * radius**2
print("the area is:" , area)
# Out:
# enter the radius 20
# the area is: 1256.0
